# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
lines_read = []
with open('events.txt', 'r') as f:
    for line in f:
        line = line.replace('\n', '').split(' ')
        if float(line[0]) > 1:
            break
        lines_read.append(line)
lines_read
# Out:
# [['0.000000000', '33', '39', '1'],
#  ['0.000011001', '158', '145', '1'],
#  ['0.000050000', '88', '143', '0'],
#  ['0.000055000', '174', '154', '0'],
#  ['0.000080001', '112', '139', '1'],
#  ['0.000123000', '136', '171', '0'],
#  ['0.000130001', '173', '90', '0'],
#  ['0.000139001', '106', '140', '0'],
#  ['0.000148001', '192', '79', '1'],
#  ['0.000191001', '118', '149', '0'],
#  ['0.000223000', '191', '95', '0'],
#  ['0.000223000', '192', '10', '1'],
#  ['0.000244000', '181', '130', '1'],
#  ['0.000273000', '189', '74', '1'],
#  ['0.000283000', '136', '170', '0'],
#  ['0.000309000', '20', '39', '1'],
#  ['0.000319001', '131', '35', '1'],
#  ['0.000401000', '144', '170', '0'],
#  ['0.000422001', '18', '110', '0'],
#  ['0.000424001', '110', '43', '0'],
#  ['0.000448001', '151', '148', '1'],
#  ['0.000490001', '98', '124', '1'],
#  ['0.000502001', '186', '147', '0'],
#  ['0.000514001', '100', '128', '1'],
#  ['0.000639000', '19', '117', '0'],
#  ['0.000661001', '89', '143', '0'],
#  ['0.000688000', '183', '97', '0'],
#  ['0.000689000', '158', '163', '0'],
#  ['0.000693000', '19', '115', '0'],
#  ['0.000718001', '139', '153', '1'],
#  ['0.000725001', '132', '36', '0'],
#  ['0.000733000', '200', '24', '1'],
#  ['0.000754001', '238', '81', '0'],
#  ['0.000760000', '123', '50', '0'],
#  ['0.000838000', '125', '47', '1'],
#  ['0.000940000', '202', '6', '1'],
#  ['0.000940000', '179', '74', '1'],
#  ['0.001004000', '27', '116', '0'],
#  ['0.001033000', '239', '157', '1'],
#  ['0.001067001', '148', '168', '1'],
#  ['0.001080000', '89', '144', '0'],
#  ['0.001174001', '207', '9', '1'],
#  ['0.001222000', '36', '104', '1'],
#  ['0.001235001', '235', '177', '0'],
#  ['0.001256000', '94', '143', '0'],
#  ['0.001347001', '204', '14', '0'],
#  ['0.001351000', '143', '152', '1'],
#  ['0.001397001', '199', '22', '0'],
#  ['0.001534000', '147', '168', '0'],
#  ['0.001562000', '132', '162', '0'],
#  ['0.001573001', '135', '169', '1'],
#  ['0.001628000', '119', '48', '0'],
#  ['0.001642001', '109', '37', '1'],
#  ['0.001705001', '194', '89', '0'],
#  ['0.001787000', '194', '83', '1'],
#  ['0.001819001', '17', '97', '0'],
#  ['0.001835000', '148', '150', '1'],
#  ['0.001841001', '175', '93', '1'],
#  ['0.001866000', '118', '31', '1'],
#  ['0.001869001', '167', '158', '0'],
#  ['0.001877000', '139', '172', '0'],
#  ['0.001895001', '35', '40', '1'],
#  ['0.001928000', '187', '74', '1'],
#  ['0.001930000', '142', '153', '1'],
#  ['0.001948001', '207', '12', '0'],
#  ['0.001960001', '128', '38', '0'],
#  ['0.002038001', '40', '108', '1'],
#  ['0.002047001', '103', '39', '0'],
#  ['0.002125000', '104', '40', '0'],
#  ['0.002179000', '96', '122', '1'],
#  ['0.002188000', '31', '52', '0'],
#  ['0.002191000', '87', '144', '0'],
#  ['0.002200000', '201', '6', '1'],
#  ['0.002205000', '178', '73', '1'],
#  ['0.002254001', '140', '172', '0'],
#  ['0.002261001', '169', '139', '1'],
#  ['0.002311001', '177', '134', '1'],
#  ['0.002422001', '106', '134', '1'],
#  ['0.002502000', '171', '156', '1'],
#  ['0.002582000', '207', '25', '0'],
#  ['0.002638001', '112', '37', '1'],
#  ['0.002645001', '109', '135', '1'],
#  ['0.002671001', '149', '167', '0'],
#  ['0.002734000', '103', '130', '1'],
#  ['0.002758000', '206', '25', '0'],
#  ['0.002762001', '155', '146', '1'],
#  ['0.002786001', '97', '142', '0'],
#  ['0.002805001', '129', '38', '0'],
#  ['0.002836000', '177', '74', '1'],
#  ['0.002838001', '193', '81', '1'],
#  ['0.002858000', '110', '140', '0'],
#  ['0.002906001', '124', '36', '1'],
#  ['0.002990001', '37', '104', '1'],
#  ['0.003006001', '93', '117', '1'],
#  ['0.003013001', '239', '179', '0'],
#  ['0.003064000', '182', '96', '0'],
#  ['0.003136000', '29', '117', '0'],
#  ['0.003168001', '173', '154', '0'],
#  ['0.003253001', '184', '97', '0'],
#  ['0.003294000', '162', '143', '1'],
#  ['0.003332000', '114', '49', '0'],
#  ['0.003375000', '187', '143', '1'],
#  ['0.003392000', '130', '37', '0'],
#  ['0.003404000', '126', '40', '0'],
#  ['0.003406000', '134', '166', '0'],
#  ['0.003483001', '180', '150', '0'],
#  ['0.003492000', '186', '140', '1'],
#  ['0.003510000', '88', '144', '0'],
#  ['0.003566001', '106', '141', '0'],
#  ['0.003617000', '205', '19', '1'],
#  ['0.003622000', '172', '155', '0'],
#  ['0.003640001', '163', '160', '0'],
#  ['0.003781000', '197', '22', '0'],
#  ['0.003840000', '208', '10', '1'],
#  ['0.003862000', '176', '153', '0'],
#  ['0.003910001', '157', '163', '0'],
#  ['0.003934001', '183', '74', '1'],
#  ['0.004119001', '206', '19', '1'],
#  ['0.004178000', '129', '35', '1'],
#  ['0.004224001', '202', '24', '0'],
#  ['0.004240001', '133', '166', '0'],
#  ['0.004251000', '94', '118', '1'],
#  ['0.004303000', '108', '135', '1'],
#  ['0.004395001', '103', '141', '0'],
#  ['0.004409001', '116', '27', '1'],
#  ['0.004448000', '95', '120', '1'],
#  ['0.004467000', '236', '178', '0'],
#  ['0.004492001', '115', '30', '1'],
#  ['0.004494001', '179', '151', '0'],
#  ['0.004665001', '122', '36', '1'],
#  ['0.004715001', '102', '129', '1'],
#  ['0.004786001', '188', '146', '0'],
#  ['0.004808001', '184', '73', '1'],
#  ['0.004825000', '180', '151', '0'],
#  ['0.004854000', '116', '47', '0'],
#  ['0.004862001', '164', '159', '0'],
#  ['0.004970000', '155', '144', '1'],
#  ['0.004974001', '105', '132', '1'],
#  ['0.005011000', '185', '96', '0'],
#  ['0.005035001', '193', '90', '0'],
#  ['0.005050001', '143', '151', '1'],
#  ['0.005072000', '234', '170', '0'],
#  ['0.005128001', '109', '137', '1'],
#  ['0.005148000', '26', '99', '1'],
#  ['0.005177000', '134', '157', '1'],
#  ['0.005232001', '118', '46', '0'],
#  ['0.005267000', '152', '166', '0'],
#  ['0.005346001', '18', '105', '0'],
#  ['0.005359000', '190', '75', '1'],
#  ['0.005426000', '105', '133', '1'],
#  ['0.005453001', '138', '155', '1'],
#  ['0.005496001', '182', '131', '1'],
#  ['0.005536001', '84', '145', '0'],
#  ['0.005536001', '188', '145', '1'],
#  ['0.005567001', '132', '164', '0'],
#  ['0.005662001', '205', '13', '0'],
#  ['0.005725000', '139', '155', '1'],
#  ['0.005788001', '19', '116', '0'],
#  ['0.005943000', '18', '108', '0'],
#  ['0.006026000', '105', '37', '1'],
#  ['0.006034000', '181', '96', '0'],
#  ['0.006043000', '108', '137', '1'],
#  ['0.006043000', '169', '137', '1'],
#  ['0.006044001', '82', '145', '0'],
#  ['0.006062000', '197', '21', '0'],
#  ['0.006208001', '238', '179', '0'],
#  ['0.006479001', '178', '152', '0'],
#  ['0.006544000', '195', '6', '1'],
#  ['0.006569001', '125', '41', '0'],
#  ['0.006609001', '170', '156', '0'],
#  ['0.006678001', '236', '177', '0'],
#  ['0.006723001', '120', '47', '0'],
#  ['0.006805000', '107', '37', '1'],
#  ['0.006816001', '18', '106', '0'],
#  ['0.006817000', '169', '86', '0'],
#  ['0.006853000', '208', '11', '0'],
#  ['0.006944001', '40', '50', '0'],
#  ['0.007053001', '135', '155', '1'],
#  ['0.007140000', '190', '97', '0'],
#  ['0.007146001', '204', '25', '0'],
#  ['0.007174001', '165', '159', '0'],
#  ['0.007189000', '237', '178', '0'],
#  ['0.007252001', '116', '48', '0'],
#  ['0.007301000', '175', '135', '1'],
#  ['0.007462000', '145', '152', '1'],
#  ['0.007479000', '176', '74', '1'],
#  ['0.007487001', '95', '121', '1'],
#  ['0.007547001', '101', '142', '0'],
#  ['0.007615000', '192', '93', '0'],
#  ['0.007655000', '137', '173', '0'],
#  ['0.007659000', '119', '46', '0'],
#  ['0.007912001', '131', '157', '1'],
#  ['0.008050001', '165', '139', '1'],
#  ['0.008077000', '25', '94', '1'],
#  ['0.008082000', '93', '143', '0'],
#  ['0.008093001', '112', '51', '0'],
#  ['0.008109001', '202', '25', '0'],
#  ['0.008246000', '108', '140', '0'],
#  ['0.008382001', '158', '143', '1'],
#  ['0.008505000', '191', '77', '1'],
#  ['0.008566000', '124', '42', '0'],
#  ['0.008591001', '117', '29', '1'],
#  ['0.008612001', '107', '135', '1'],
#  ['0.008860000', '101', '128', '1'],
#  ['0.008919001', '181', '74', '1'],
#  ['0.009278000', '181', '150', '0'],
#  ['0.009367001', '110', '137', '1'],
#  ['0.009397000', '104', '132', '1'],
#  ['0.009450001', '32', '105', '1'],
#  ['0.009512001', '174', '92', '1'],
#  ['0.009583001', '112', '50', '0'],
#  ['0.009583001', '98', '142', '0'],
#  ['0.009689000', '200', '23', '0'],
#  ['0.009765000', '188', '144', '1'],
#  ['0.009928001', '204', '7', '1'],
#  ['0.010071000', '124', '50', '0'],
#  ['0.010098001', '208', '22', '1'],
#  ['0.010178000', '234', '174', '0'],
#  ['0.010383001', '40', '49', '0'],
#  ['0.010391000', '130', '160', '0'],
#  ['0.010396000', '122', '49', '0'],
#  ['0.010446000', '103', '131', '1'],
#  ['0.010614000', '106', '132', '1'],
#  ['0.010754001', '26', '100', '1'],
#  ['0.010866000', '116', '46', '0'],
#  ['0.010872001', '24', '52', '0'],
#  ['0.010885000', '133', '164', '0'],
#  ['0.010942000', '185', '74', '1'],
#  ['0.010992000', '208', '25', '0'],
#  ['0.011060001', '25', '38', '1'],
#  ['0.011113000', '172', '90', '0'],
#  ['0.011142000', '17', '98', '0'],
#  ['0.011157001', '145', '151', '1'],
#  ['0.011284000', '144', '153', '1'],
#  ['0.011286000', '175', '153', '0'],
#  ['0.011364001', '188', '74', '1'],
#  ['0.011370001', '163', '140', '1'],
#  ['0.011394001', '138', '173', '0'],
#  ['0.011432001', '18', '107', '0'],
#  ['0.011455000', '40', '110', '1'],
#  ['0.011475001', '117', '47', '0'],
#  ['0.011532001', '194', '7', '1'],
#  ['0.011557000', '172', '135', '1'],
#  ['0.011669000', '155', '164', '0'],
#  ['0.011672001', '137', '154', '1'],
#  ['0.011699000', '186', '74', '1'],
#  ['0.011756000', '40', '43', '1'],
#  ['0.011777001', '172', '155', '0'],
#  ['0.011781001', '178', '134', '1'],
#  ['0.011812001', '156', '164', '1'],
#  ['0.011816000', '192', '79', '1'],
#  ['0.011867001', '184', '148', '1'],
#  ['0.012010000', '182', '132', '1'],
#  ['0.012258001', '93', '119', '1'],
#  ['0.012310001', '125', '36', '1'],
#  ['0.012312000', '86', '132', '0'],
#  ['0.012553001', '17', '99', '0'],
#  ['0.012718000', '204', '18', '1'],
#  ['0.012810000', '183', '134', '1'],
#  ['0.012836000', '185', '138', '1'],
#  ['0.012993000', '95', '143', '0'],
#  ['0.013024000', '96', '123', '1'],
#  ['0.013131000', '182', '74', '1'],
#  ['0.013197000', '100', '126', '1'],
#  ['0.013214000', '239', '179', '0'],
#  ['0.013285000', '160', '142', '1'],
#  ['0.013312001', '102', '141', '0'],
#  ['0.013362001', '179', '133', '1'],
#  ['0.013462001', '183', '133', '1'],
#  ['0.013538001', '121', '36', '1'],
#  ['0.013566001', '181', '132', '1'],
#  ['0.013589000', '180', '74', '1'],
#  ['0.013620000', '153', '147', '1'],
#  ['0.013721000', '238', '179', '0'],
#  ['0.013866000', '107', '141', '0'],
#  ['0.014026001', '40', '109', '1'],
#  ['0.014035000', '97', '124', '1'],
#  ['0.014063000', '206', '8', '1'],
#  ['0.014070000', '125', '51', '0'],
#  ['0.014234000', '174', '95', '0'],
#  ['0.014248000', '194', '83', '1'],
#  ['0.014259001', '183', '149', '0'],
#  ['0.014484000', '34', '39', '1'],
#  ['0.014508001', '101', '127', '1'],
#  ['0.014569000', '136', '155', '1'],
#  ['0.014589001', '91', '116', '1'],
#  ['0.014673000', '105', '40', '0'],
#  ['0.014697000', '130', '161', '0'],
#  ['0.014706000', '159', '162', '0'],
#  ['0.014801000', '105', '134', '1'],
#  ['0.014861000', '177', '97', '0'],
#  ['0.014866000', '99', '126', '1'],
#  ['0.014903000', '187', '142', '1'],
#  ['0.014914001', '198', '5', '1'],
#  ['0.014998000', '184', '136', '1'],
#  ['0.015135001', '153', '148', '1'],
#  ['0.015221001', '170', '88', '0'],
#  ['0.015361001', '90', '144', '0'],
#  ['0.015475000', '127', '52', '0'],
#  ['0.015501001', '19', '116', '0'],
#  ['0.015590000', '88', '126', '0'],
#  ['0.015673000', '136', '157', '1'],
#  ['0.015703000', '237', '179', '0'],
#  ['0.015748000', '110', '37', '1'],
#  ['0.015882000', '19', '118', '0'],
#  ['0.015925001', '137', '172', '0'],
#  ['0.015930001', '136', '171', '0'],
#  ['0.016000000', '177', '152', '0'],
#  ['0.016042001', '133', '166', '0'],
#  ['0.016179001', '18', '104', '0'],
#  ['0.016196001', '136', '169', '0'],
#  ['0.016228000', '186', '141', '1'],
#  ['0.016414001', '18', '109', '0'],
#  ['0.016477000', '189', '74', '1'],
#  ['0.016482000', '111', '37', '1'],
#  ['0.016519001', '234', '176', '0'],
#  ['0.016530000', '173', '94', '0'],
#  ['0.016538001', '21', '95', '1'],
#  ['0.016607001', '236', '178', '0'],
#  ['0.016687001', '185', '139', '1'],
#  ['0.016695000', '184', '137', '1'],
#  ['0.016716001', '131', '163', '0'],
#  ['0.016784001', '125', '39', '0'],
#  ['0.016977001', '203', '14', '0'],
#  ['0.017000001', '130', '35', '1'],
#  ['0.017155001', '86', '133', '0'],
#  ['0.017184000', '92', '118', '1'],
#  ['0.017206000', '238', '159', '1'],
#  ['0.017231001', '17', '97', '0'],
#  ['0.017290001', '95', '122', '1'],
#  ['0.017471001', '174', '96', '0'],
#  ['0.017527001', '19', '114', '0'],
#  ['0.017543000', '94', '143', '0'],
#  ['0.017805001', '206', '20', '1'],
#  ['0.017892000', '141', '152', '1'],
#  ['0.017902001', '233', '175', '0'],
#  ['0.018070000', '17', '100', '0'],
#  ['0.018088001', '119', '33', '1'],
#  ['0.018126001', '101', '141', '0'],
#  ['0.018339001', '172', '92', '0'],
#  ['0.018395000', '207', '21', '1'],
#  ['0.018469000', '178', '74', '1'],
#  ['0.018469000', '184', '74', '1'],
#  ['0.018601000', '42', '46', '1'],
#  ['0.018615001', '174', '154', '0'],
#  ['0.018635000', '98', '126', '1'],
#  ['0.018702001', '83', '142', '0'],
#  ['0.018744000', '124', '45', '1'],
#  ['0.018825000', '176', '96', '0'],
#  ['0.018900001', '134', '168', '0'],
#  ['0.018936000', '89', '124', '0'],
#  ['0.019014000', '239', '81', '1'],
#  ['0.019167000', '106', '41', '0'],
#  ['0.019227001', '111', '43', '0'],
#  ['0.019289001', '123', '36', '1'],
#  ['0.019327001', '126', '49', '1'],
#  ['0.019478001', '177', '96', '0'],
#  ['0.019640001', '182', '73', '1'],
#  ['0.019641000', '181', '97', '0'],
#  ['0.019881000', '171', '90', '0'],
#  ['0.019934001', '84', '139', '0'],
#  ['0.020003001', '138', '173', '0'],
#  ['0.020012000', '19', '117', '0'],
#  ['0.020343001', '104', '133', '1'],
#  ['0.020498000', '18', '108', '0'],
#  ['0.020508000', '109', '41', '0'],
#  ['0.020658001', '18', '110', '0'],
#  ['0.020684001', '200', '24', '1'],
#  ['0.020719000', '17', '96', '0'],
#  ['0.020734001', '99', '127', '1'],
#  ['0.020775001', '15', '46', '0'],
#  ['0.020806000', '201', '24', '1'],
#  ['0.020835000', '190', '75', '1'],
#  ['0.020870001', '196', '6', '1'],
#  ['0.021010001', '107', '136', '1'],
#  ['0.021019001', '92', '119', '1'],
#  ['0.021059001', '100', '142', '0'],
#  ['0.021191000', '42', '45', '1'],
#  ['0.021338000', '238', '179', '0'],
#  ['0.021413001', '172', '91', '0'],
#  ['0.021481000', '153', '165', '1'],
#  ['0.021484001', '126', '36', '1'],
#  ['0.021516000', '18', '107', '0'],
#  ['0.021685000', '17', '101', '0'],
#  ['0.021737000', '18', '106', '0'],
#  ['0.021774001', '37', '41', '1'],
#  ['0.021925000', '135', '167', '0'],
#  ['0.022012000', '161', '161', '0'],
#  ['0.022049001', '110', '43', '0'],
#  ['0.022113001', '86', '144', '0'],
#  ['0.022246001', '192', '14', '0'],
#  ['0.022279001', '108', '42', '0'],
#  ['0.022299000', '19', '115', '0'],
#  ['0.022449000', '165', '141', '1'],
#  ['0.022488001', '200', '6', '1'],
#  ['0.022529001', '182', '133', '1'],
#  ['0.022557001', '103', '129', '1'],
#  ['0.022745001', '134', '167', '0'],
#  ['0.022746000', '187', '141', '1'],
#  ['0.023108001', '89', '124', '0'],
#  ['0.023184001', '187', '74', '1'],
#  ['0.023312001', '124', '36', '1'],
#  ['0.023360000', '193', '81', '1'],
#  ['0.023652000', '101', '129', '1'],
#  ['0.023673001', '96', '124', '1'],
#  ['0.023677001', '97', '123', '1'],
#  ['0.023709000', '172', '89', '0'],
#  ['0.023713001', '135', '169', '1'],
#  ['0.023731000', '125', '35', '1'],
#  ['0.023934001', '102', '131', '1'],
#  ['0.024023000', '16', '48', '0'],
#  ['0.024164001', '194', '18', '0'],
#  ['0.024246000', '132', '163', '0'],
#  ['0.024514000', '99', '125', '1'],
#  ['0.024678000', '201', '6', '1'],
#  ['0.024702000', '106', '133', '1'],
#  ['0.024824001', '205', '25', '0'],
#  ['0.024900001', '92', '117', '1'],
#  ['0.024935001', '94', '121', '1'],
#  ['0.024979000', '93', '118', '1'],
#  ['0.025031000', '38', '104', '1'],
#  ['0.025054001', '203', '25', '0'],
#  ['0.025209000', '17', '98', '0'],
#  ['0.025222001', '188', '146', '0'],
#  ['0.025353001', '183', '135', '1'],
#  ['0.025359000', '86', '143', '0'],
#  ['0.025459000', '102', '141', '0'],
#  ['0.025606000', '199', '23', '1'],
#  ['0.025677000', '125', '47', '1'],
#  ['0.025726001', '166', '158', '0'],
#  ['0.025773001', '26', '101', '1'],
#  ['0.025898000', '137', '173', '0'],
#  ['0.025964000', '33', '115', '0'],
#  ['0.026045000', '238', '80', '1'],
#  ['0.026119000', '207', '25', '1'],
#  ['0.026178000', '84', '138', '0'],
#  ['0.026212001', '85', '135', '0'],
#  ['0.026305001', '27', '106', '1'],
#  ['0.026390001', '175', '97', '0'],
#  ['0.026476001', '98', '124', '1'],
#  ['0.026660000', '94', '119', '1'],
#  ['0.026790000', '234', '175', '0'],
#  ['0.026922001', '133', '165', '0'],
#  ['0.027013000', '109', '138', '1'],
#  ['0.027018000', '108', '53', '0'],
#  ['0.027078000', '104', '141', '0'],
#  ['0.027250001', '186', '140', '1'],
#  ['0.027445000', '26', '99', '1'],
#  ['0.027551001', '107', '134', '1'],
#  ['0.027604000', '18', '106', '0'],
#  ['0.027854000', '193', '17', '0'],
#  ['0.027964001', '132', '164', '0'],
#  ['0.028183000', '124', '44', '1'],
#  ['0.028436001', '84', '144', '0'],
#  ['0.028447000', '17', '97', '0'],
#  ['0.028527001', '196', '20', '0'],
#  ['0.028577000', '196', '21', '0'],
#  ['0.028632000', '185', '137', '1'],
#  ['0.028634000', '130', '161', '0'],
#  ['0.028705001', '104', '40', '0'],
#  ['0.028744000', '86', '135', '0'],
#  ['0.028925001', '123', '50', '0'],
#  ['0.029351000', '187', '146', '0'],
#  ['0.029352001', '167', '158', '0'],
#  ['0.029370000', '17', '103', '0'],
#  ['0.029470000', '117', '28', '1'],
#  ['0.029479000', '170', '86', '0'],
#  ['0.029521001', '20', '50', '0'],
#  ['0.029603000', '234', '177', '0'],
#  ['0.029665000', '120', '48', '0'],
#  ['0.029842001', '20', '118', '0'],
#  ['0.029915001', '24', '52', '0'],
#  ['0.030043001', '119', '48', '0'],
#  ['0.030069001', '195', '20', '0'],
#  ['0.030202001', '133', '166', '0'],
#  ['0.030304001', '19', '116', '0'],
#  ['0.030346000', '205', '8', '1'],
#  ['0.030517000', '197', '22', '0'],
#  ['0.030662000', '104', '131', '1'],
#  ['0.030663001', '102', '142', '0'],
#  ['0.030670001', '82', '145', '0'],
#  ['0.030735000', '202', '6', '1'],
#  ['0.030815001', '121', '49', '0'],
#  ['0.030920000', '192', '79', '1'],
#  ['0.030978001', '144', '166', '0'],
#  ['0.030980000', '18', '112', '0'],
#  ['0.031035001', '134', '166', '0'],
#  ['0.031046000', '184', '135', '1'],
#  ['0.031066001', '182', '132', '1'],
#  ['0.031067000', '119', '34', '1'],
#  ['0.031074000', '93', '121', '1'],
#  ['0.031129000', '112', '37', '1'],
#  ['0.031149001', '180', '133', '1'],
#  ['0.031162000', '18', '109', '0'],
#  ['0.031526000', '120', '36', '1'],
#  ['0.031670000', '109', '42', '0'],
#  ['0.031681001', '94', '122', '1'],
#  ['0.031823001', '36', '116', '0'],
#  ['0.032188000', '188', '144', '1'],
#  ['0.032297000', '15', '47', '0'],
#  ['0.032337000', '26', '103', '1'],
#  ['0.032592001', '196', '19', '0'],
#  ['0.032624000', '21', '51', '0'],
#  ['0.032690001', '163', '158', '0'],
#  ['0.032703000', '18', '110', '0'],
#  ['0.032747001', '41', '44', '1'],
#  ['0.032858001', '34', '105', '1'],
#  ['0.032987000', '172', '92', '0'],
#  ['0.033033000', '36', '40', '1'],
#  ['0.033078000', '17', '100', '0'],
#  ['0.033285001', '138', '154', '1'],
#  ['0.033289000', '208', '10', '1'],
#  ['0.033348000', '42', '47', '1'],
#  ['0.033407001', '26', '102', '1'],
#  ['0.033454001', '192', '13', '0'],
#  ['0.033456001', '99', '142', '0'],
#  ['0.033629001', '17', '99', '0'],
#  ['0.033725001', '118', '32', '1'],
#  ['0.033866000', '135', '168', '0'],
#  ['0.034037000', '188', '97', '0'],
#  ['0.034367000', '40', '111', '1'],
#  ['0.034378000', '123', '43', '1'],
#  ['0.034523000', '18', '108', '0'],
#  ['0.034539001', '204', '25', '0'],
#  ['0.034543001', '17', '98', '0'],
#  ['0.034585000', '191', '77', '1'],
#  ['0.034590000', '26', '104', '1'],
#  ['0.034594000', '24', '94', '1'],
#  ['0.034630000', '148', '168', '0'],
#  ['0.034697000', '88', '128', '0'],
#  ['0.034754000', '205', '19', '1'],
#  ['0.034840001', '97', '125', '1'],
#  ['0.035181000', '164', '142', '1'],
#  ['0.035293001', '207', '9', '1'],
#  ['0.035420000', '39', '42', '1'],
#  ['0.035499000', '152', '146', '1'],
#  ['0.035532000', '37', '116', '0'],
#  ['0.035572000', '88', '144', '0'],
#  ['0.035656001', '174', '26', '1'],
#  ['0.035690001', '17', '49', '0'],
#  ['0.035842001', '31', '105', '1'],
#  ['0.035971000', '236', '178', '0'],
#  ['0.036063001', '204', '18', '1'],
#  ['0.036140000', '106', '141', '0'],
#  ['0.036216000', '26', '105', '1'],
#  ['0.036394000', '157', '163', '0'],
#  ['0.036533001', '204', '7', '1'],
#  ['0.036676000', '25', '52', '0'],
#  ['0.037036001', '146', '169', '0'],
#  ['0.037197001', '41', '114', '1'],
#  ['0.037332001', '172', '155', '0'],
#  ['0.037425001', '195', '85', '1'],
#  ['0.037672001', '144', '170', '0'],
#  ['0.037858000', '138', '173', '0'],
#  ['0.037895001', '140', '172', '0'],
#  ['0.037902001', '184', '136', '1'],
#  ['0.038100000', '198', '21', '0'],
#  ['0.038145000', '131', '163', '0'],
#  ['0.038172001', '178', '132', '1'],
#  ['0.038176000', '118', '31', '1'],
#  ['0.038228000', '183', '74', '1'],
#  ['0.038253001', '23', '52', '0'],
#  ['0.038357000', '28', '117', '0'],
#  ['0.038452000', '186', '97', '0'],
#  ['0.038600001', '38', '41', '1'],
#  ['0.038666001', '19', '50', '0'],
#  ['0.038849001', '21', '118', '0'],
#  ['0.038887001', '193', '82', '1'],
#  ['0.038925001', '38', '116', '0'],
#  ['0.038964000', '163', '160', '0'],
#  ['0.038975001', '152', '166', '0'],
#  ['0.038986000', '182', '96', '0'],
#  ['0.038991001', '96', '122', '1'],
#  ['0.039000000', '20', '95', '1'],
#  ['0.039016000', '29', '116', '0'],
#  ['0.039024000', '83', '145', '0'],
#  ['0.039090000', '154', '165', '0'],
#  ['0.039126000', '160', '162', '0'],
#  ['0.039160001', '19', '117', '0'],
#  ['0.039162001', '202', '25', '0'],
#  ['0.039335001', '176', '153', '0'],
#  ['0.039352001', '183', '149', '0'],
#  ['0.039442001', '110', '43', '0'],
#  ['0.039659000', '102', '38', '1'],
#  ['0.039665001', '118', '47', '0'],
#  ['0.039668001', '130', '160', '0'],
#  ['0.039768001', '203', '17', '1'],
#  ['0.039836001', '194', '83', '1'],
#  ['0.039881001', '150', '167', '0'],
#  ['0.040001000', '109', '136', '1'],
#  ['0.040064001', '22', '118', '0'],
#  ['0.040074001', '27', '117', '0'],
#  ['0.040103000', '111', '139', '1'],
#  ['0.040104000', '108', '141', '0'],
#  ['0.040234000', '31', '39', '1'],
#  ['0.040460000', '103', '141', '0'],
#  ['0.040482001', '105', '141', '0'],
#  ['0.040490000', '186', '74', '1'],
#  ['0.040710001', '84', '145', '0'],
#  ['0.040722001', '89', '144', '0'],
#  ['0.040743001', '102', '39', '0'],
#  ['0.040820000', '35', '52', '0'],
#  ['0.040834000', '104', '141', '0'],
#  ['0.041223001', '176', '133', '1'],
#  ['0.041371000', '142', '171', '0'],
#  ['0.041397000', '137', '156', '1'],
#  ['0.041443001', '140', '153', '1'],
#  ['0.041513000', '35', '40', '1'],
#  ['0.041560001', '19', '95', '1'],
#  ['0.041841000', '125', '51', '0'],
#  ['0.041855000', '34', '52', '0'],
#  ['0.042058001', '32', '39', '1'],
#  ['0.042120001', '107', '41', '0'],
#  ['0.042141001', '96', '143', '0'],
#  ['0.042287000', '194', '84', '1'],
#  ['0.042352001', '30', '105', '1'],
#  ['0.042366001', '98', '125', '1'],
#  ['0.042376001', '26', '100', '1'],
#  ['0.042387000', '22', '51', '0'],
#  ['0.042419001', '133', '157', '1'],
#  ['0.042677001', '17', '48', '0'],
#  ['0.042678001', '160', '144', '1'],
#  ['0.042789001', '174', '154', '0'],
#  ['0.043004000', '181', '150', '0'],
#  ['0.043006000', '165', '159', '0'],
#  ['0.043022001', '32', '116', '0'],
#  ['0.043022001', '179', '151', '0'],
#  ['0.043048001', '120', '35', '1'],
#  ['0.043381000', '154', '145', '1'],
#  ['0.043591001', '156', '164', '0'],
#  ['0.043653001', '141', '153', '1'],
#  ['0.043701001', '29', '117', '0'],
#  ['0.043701001', '30', '117', '0'],
#  ['0.043778000', '145', '150', '1'],
#  ['0.043977000', '111', '140', '0'],
#  ['0.044051000', '94', '143', '0'],
#  ['0.044076001', '122', '36', '1'],
#  ['0.044146000', '109', '140', '0'],
#  ['0.044148000', '91', '143', '0'],
#  ['0.044246001', '147', '149', '1'],
#  ['0.044255000', '34', '40', '1'],
#  ['0.044555001', '194', '17', '0'],
#  ['0.044589000', '188', '74', '1'],
#  ['0.044619001', '186', '147', '0'],
#  ['0.044681001', '171', '136', '1'],
#  ['0.044888000', '36', '52', '0'],
#  ['0.044965000', '103', '130', '1'],
#  ['0.045099001', '149', '148', '1'],
#  ['0.045110001', '146', '150', '1'],
#  ['0.045168000', '18', '40', '1'],
#  ['0.045213001', '158', '163', '0'],
#  ['0.045291001', '101', '142', '0'],
#  ['0.045314001', '21', '51', '0'],
#  ['0.045461000', '89', '143', '0'],
#  ['0.045575000', '26', '117', '0'],
#  ['0.045749001', '125', '36', '1'],
#  ['0.045782001', '36', '104', '1'],
#  ['0.045937000', '24', '52', '0'],
#  ['0.045960001', '183', '73', '1'],
#  ['0.046017001', '37', '41', '1'],
#  ['0.046086001', '108', '37', '1'],
#  ['0.046238001', '100', '142', '0'],
#  ['0.046252001', '159', '162', '0'],
#  ['0.046318001', '166', '140', '1'],
#  ['0.046345001', '152', '166', '0'],
#  ['0.046534001', '148', '151', '1'],
#  ['0.046537001', '30', '53', '0'],
#  ['0.046567000', '124', '51', '0'],
#  ['0.046655001', '90', '144', '0'],
#  ['0.046703001', '185', '74', '1'],
#  ['0.046741001', '106', '41', '0'],
#  ['0.046756000', '144', '170', '0'],
#  ['0.046833001', '167', '158', '0'],
#  ['0.046897000', '178', '152', '0'],
#  ['0.046934000', '90', '143', '0'],
#  ['0.046964001', '171', '156', '1'],
#  ['0.047017000', '37', '116', '0'],
#  ['0.047081001', '124', '36', '1'],
#  ['0.047295000', '179', '74', '1'],
#  ['0.047328000', '176', '153', '0'],
#  ['0.047405000', '107', '141', '0'],
#  ['0.047421000', '172', '155', '0'],
#  ['0.047465001', '166', '139', '1'],
#  ['0.047522001', '159', '144', '1'],
#  ['0.047523000', '130', '158', '1'],
#  ['0.047580000', '21', '39', '1'],
#  ['0.047589000', '102', '142', '0'],
#  ['0.047740001', '103', '38', '1'],
#  ['0.047956001', '157', '163', '0'],
#  ['0.048059000', '161', '161', '0'],
#  ['0.048093000', '108', '42', '0'],
#  ['0.048094001', '127', '36', '1'],
#  ['0.048102000', '40', '43', '1'],
#  ['0.048138000', '104', '38', '1'],
#  ['0.048172001', '95', '143', '0'],
#  ['0.048198001', '146', '169', '0'],
#  ['0.048223000', '36', '116', '0'],
#  ['0.048224001', '104', '40', '0'],
#  ['0.048298001', '106', '141', '0'],
#  ['0.048359000', '20', '118', '0'],
#  ['0.048394000', '148', '168', '0'],
#  ['0.048406000', '22', '118', '0'],
#  ['0.048419001', '187', '147', '0'],
#  ['0.048441001', '19', '118', '0'],
#  ['0.048480000', '38', '104', '1'],
#  ['0.048501000', '108', '140', '0'],
#  ['0.048533001', '16', '48', '0'],
#  ['0.048565000', '84', '145', '0'],
#  ['0.048624000', '170', '156', '0'],
#  ['0.048805000', '238', '160', '1'],
#  ['0.048862000', '140', '172', '0'],
#  ['0.048914000', '23', '118', '0'],
#  ['0.048917001', '184', '74', '1'],
#  ['0.048922001', '169', '157', '0'],
#  ['0.049074001', '164', '140', '1'],
#  ['0.049120000', '29', '52', '0'],
#  ['0.049149000', '28', '117', '0'],
#  ['0.049178000', '93', '143', '0'],
#  ['0.049367000', '38', '105', '1'],
#  ['0.049436000', '30', '39', '1'],
#  ['0.049476000', '15', '47', '0'],
#  ['0.049498000', '38', '115', '0'],
#  ['0.049567000', '192', '14', '0'],
#  ['0.049610000', '20', '51', '0'],
#  ['0.049628000', '34', '116', '0'],
#  ['0.049800001', '39', '116', '0'],
#  ['0.049821000', '165', '159', '0'],
#  ['0.049911000', '85', '144', '0'],
#  ['0.049912001', '117', '29', '1'],
#  ['0.049975000', '185', '148', '1'],
#  ['0.049989000', '200', '24', '1'],
#  ['0.050202001', '138', '173', '0'],
#  ['0.050316001', '183', '149', '0'],
#  ['0.050358001', '35', '116', '0'],
#  ['0.050406001', '18', '50', '0'],
#  ['0.050412000', '38', '42', '1'],
#  ['0.050447000', '86', '144', '0'],
#  ['0.050455000', '21', '118', '0'],
#  ['0.050499000', '182', '150', '0'],
#  ['0.050506001', '87', '144', '0'],
#  ['0.050558001', '38', '116', '0'],
#  ['0.050597000', '17', '49', '0'],
#  ['0.050686001', '92', '143', '0'],
#  ['0.050694000', '129', '38', '0'],
#  ['0.050698001', '23', '117', '0'],
#  ['0.050714001', '36', '68', '0'],
#  ['0.050721001', '37', '52', '0'],
#  ['0.050880001', '132', '157', '1'],
#  ['0.050975001', '21', '95', '1'],
#  ['0.051012000', '148', '168', '0'],
#  ['0.051016001', '22', '95', '1'],
#  ['0.051074000', '39', '51', '0'],
#  ['0.051280000', '24', '118', '0'],
#  ['0.051292000', '23', '52', '0'],
#  ['0.051376001', '113', '50', '0'],
#  ['0.051381001', '37', '104', '1'],
#  ['0.051489000', '103', '39', '0'],
#  ['0.051533001', '197', '6', '1'],
#  ['0.051678001', '31', '117', '0'],
#  ['0.051683001', '33', '116', '0'],
#  ['0.051692001', '144', '151', '1'],
#  ['0.051796000', '188', '146', '0'],
#  ['0.051873001', '22', '39', '1'],
#  ['0.052019000', '117', '47', '0'],
#  ['0.052030000', '150', '167', '0'],
#  ['0.052107001', '159', '142', '1'],
#  ['0.052129001', '28', '53', '0'],
#  ['0.052135000', '110', '140', '0'],
#  ['0.052193001', '95', '121', '1'],
#  ['0.052211000', '29', '53', '0'],
#  ['0.052245001', '162', '141', '1'],
#  ['0.052271001', '126', '36', '1'],
#  ['0.052290001', '103', '132', '1'],
#  ['0.052308000', '24', '52', '0'],
#  ['0.052353000', '154', '165', '0'],
#  ['0.052424000', '91', '144', '0'],
#  ['0.052458000', '31', '105', '1'],
#  ['0.052485001', '168', '138', '1'],
#  ['0.052604001', '98', '142', '0'],
#  ['0.052672001', '156', '164', '0'],
#  ['0.052883000', '29', '117', '0'],
#  ['0.052908001', '111', '37', '1'],
#  ['0.052920000', '134', '156', '1'],
#  ['0.052921000', '182', '74', '1'],
#  ['0.052926001', '174', '135', '1'],
#  ['0.052975000', '142', '171', '0'],
#  ['0.052987000', '237', '159', '1'],
#  ['0.053047001', '94', '143', '0'],
#  ['0.053085001', '172', '136', '1'],
#  ['0.053133001', '30', '116', '0'],
#  ['0.053147001', '96', '143', '0'],
#  ['0.053174000', '97', '143', '0'],
#  ['0.053267000', '39', '104', '1'],
#  ['0.053272000', '131', '158', '1'],
#  ['0.053304001', '206', '25', '0'],
#  ['0.053353000', '32', '53', '0'],
#  ['0.053369000', '18', '95', '1'],
#  ['0.053431000', '167', '158', '0'],
#  ['0.053468001', '112', '37', '1'],
#  ['0.053468001', '33', '105', '1'],
#  ['0.053496001', '133', '156', '1'],
#  ['0.053507000', '139', '154', '1'],
#  ['0.053565001', '173', '135', '1'],
#  ['0.053585000', '128', '36', '1'],
#  ['0.053643001', '150', '150', '1'],
#  ['0.053662001', '140', '155', '1'],
#  ['0.053698001', '126', '52', '0'],
#  ['0.053828001', '33', '39', '1'],
#  ['0.053845001', '29', '105', '1'],
#  ['0.053879000', '132', '35', '1'],
#  ['0.053889000', '24', '95', '1'],
#  ['0.053950001', '25', '100', '1'],
#  ['0.054028001', '83', '145', '0'],
#  ['0.054180001', '162', '161', '0'],
#  ['0.054271000', '28', '106', '1'],
#  ['0.054280000', '31', '39', '1'],
#  ['0.054328000', '35', '105', '1'],
#  ['0.054352000', '18', '40', '1'],
#  ['0.054361000', '142', '152', '1'],
#  ['0.054532000', '119', '32', '1'],
#  ['0.054575000', '181', '74', '1'],
#  ['0.054579001', '152', '166', '0'],
#  ['0.054586001', '26', '98', '1'],
#  ['0.054588001', '155', '147', '1'],
#  ['0.054601000', '28', '52', '0'],
#  ['0.054633001', '153', '146', '1'],
#  ['0.054636000', '156', '145', '1'],
#  ['0.054658000', '85', '145', '0'],
#  ['0.054731000', '141', '154', '1'],
#  ['0.054742001', '180', '151', '0'],
#  ['0.054849001', '96', '142', '0'],
#  ['0.054867000', '163', '160', '0'],
#  ['0.054876000', '156', '144', '1'],
#  ['0.054994001', '164', '160', '0'],
#  ['0.055072001', '176', '153', '0'],
#  ['0.055098001', '34', '52', '0'],
#  ['0.055257001', '144', '170', '0'],
#  ['0.055377000', '234', '163', '1'],
#  ['0.055391000', '20', '95', '1'],
#  ['0.055392001', '35', '40', '1'],
#  ['0.055440001', '111', '36', '1'],
#  ['0.055515000', '128', '39', '0'],
#  ['0.055590001', '121', '49', '0'],
#  ['0.055721000', '116', '48', '0'],
#  ['0.055727001', '165', '159', '0'],
#  ['0.055767001', '235', '162', '1'],
#  ['0.055790000', '167', '140', '1'],
#  ['0.055839001', '24', '117', '0'],
#  ['0.055874001', '38', '51', '0'],
#  ['0.055893001', '89', '144', '0'],
#  ['0.056006000', '125', '41', '0'],
#  ['0.056023000', '158', '163', '0'],
#  ['0.056078001', '178', '152', '0'],
#  ['0.056090001', '84', '145', '0'],
#  ['0.056119001', '32', '105', '1'],
#  ['0.056120000', '30', '53', '0'],
#  ['0.056241000', '36', '41', '1'],
#  ['0.056253000', '30', '117', '0'],
#  ['0.056276001', '160', '162', '0'],
#  ['0.056302001', '160', '142', '1'],
#  ['0.056390001', '36', '52', '0'],
#  ['0.056435001', '24', '51', '0'],
#  ['0.056453001', '105', '141', '0'],
#  ['0.056487001', '88', '144', '0'],
#  ['0.056533000', '104', '38', '1'],
#  ['0.056533000', '105', '38', '1'],
#  ['0.056595000', '97', '142', '0'],
#  ['0.056637000', '18', '49', '0'],
#  ['0.056702000', '120', '36', '1'],
#  ['0.056754000', '150', '147', '1'],
#  ['0.056754000', '151', '147', '1'],
#  ['0.056837000', '123', '50', '0'],
#  ['0.056914001', '112', '51', '0'],
#  ['0.056952001', '99', '142', '0'],
#  ['0.056997001', '108', '141', '0'],
#  ['0.057083001', '148', '168', '1'],
#  ['0.057085001', '136', '155', '1'],
#  ['0.057147001', '15', '46', '0'],
#  ['0.057154001', '149', '150', '1'],
#  ['0.057180001', '123', '36', '1'],
#  ['0.057337001', '141', '172', '1'],
#  ['0.057343000', '174', '154', '0'],
#  ['0.057360001', '37', '115', '0'],
#  ['0.057387000', '109', '140', '0'],
#  ['0.057388000', '190', '98', '0'],
#  ['0.057477001', '102', '142', '0'],
#  ['0.057488001', '22', '52', '0'],
#  ['0.057501000', '18', '50', '0'],
#  ['0.057531001', '173', '155', '0'],
#  ['0.057533001', '180', '74', '1'],
#  ['0.057593001', '20', '50', '0'],
#  ['0.057617001', '103', '141', '0'],
#  ['0.057656000', '101', '142', '0'],
#  ['0.057714001', '20', '51', '0'],
#  ['0.057787001', '31', '53', '0'],
#  ['0.057787001', '33', '53', '0'],
#  ['0.057789000', '92', '120', '1'],
#  ['0.057816001', '159', '162', '0'],
#  ['0.057817000', '152', '166', '0'],
#  ['0.057837001', '194', '89', '0'],
#  ['0.057867000', '40', '50', '0'],
#  ['0.057870001', '26', '52', '0'],
#  ['0.057870001', '33', '52', '0'],
#  ['0.057935001', '108', '54', '0'],
#  ['0.057945000', '104', '142', '0'],
#  ['0.057952000', '22', '118', '0'],
#  ['0.057987001', '132', '159', '1'],
#  ['0.057988000', '30', '105', '1'],
#  ['0.057994001', '22', '117', '0'],
#  ['0.058001001', '86', '144', '0'],
#  ['0.058005000', '102', '141', '0'],
#  ['0.058026000', '100', '142', '0'],
#  ['0.058032001', '36', '105', '1'],
#  ['0.058045000', '27', '117', '0'],
#  ['0.058101001', '146', '169', '0'],
#  ['0.058170001', '154', '165', '0'],
#  ['0.058212001', '138', '173', '0'],
#  ['0.058236001', '181', '150', '0'],
#  ['0.058244000', '125', '51', '0'],
#  ['0.058250001', '156', '164', '0'],
#  ['0.058285000', '20', '117', '0'],
#  ['0.058309000', '180', '98', '0'],
#  ['0.058364001', '163', '141', '1'],
#  ['0.058429000', '24', '118', '0'],
#  ['0.058444000', '104', '141', '0'],
#  ['0.058480001', '90', '144', '0'],
#  ['0.058523001', '172', '155', '0'],
#  ['0.058582001', '166', '159', '0'],
#  ['0.058607000', '140', '172', '0'],
#  ['0.058638000', '175', '154', '0'],
#  ['0.058655000', '183', '149', '0'],
#  ['0.058671001', '35', '52', '0'],
#  ['0.058676000', '21', '39', '1'],
#  ['0.058679000', '149', '168', '0'],
#  ['0.058756001', '28', '117', '0'],
#  ['0.058835000', '187', '97', '0'],
#  ['0.058861000', '193', '91', '0'],
#  ['0.058868001', '150', '148', '1'],
#  ['0.058895000', '124', '42', '0'],
#  ['0.058895000', '40', '116', '0'],
#  ['0.058896001', '107', '141', '0'],
#  ['0.058917001', '146', '152', '1'],
#  ['0.058955001', '177', '74', '1'],
#  ['0.058963000', '148', '149', '1'],
#  ['0.058973000', '30', '106', '1'],
#  ['0.059091001', '25', '118', '0'],
#  ['0.059095001', '102', '39', '0'],
#  ['0.059136001', '191', '95', '0'],
#  ['0.059158000', '127', '36', '1'],
#  ['0.059176001', '143', '153', '1'],
#  ['0.059216001', '18', '96', '1'],
#  ['0.059222000', '180', '131', '1'],
#  ['0.059261001', '23', '118', '0'],
#  ['0.059276001', '145', '170', '0'],
#  ['0.059282000', '200', '6', '1'],
#  ['0.059283001', '150', '167', '0'],
#  ['0.059285001', '188', '98', '0'],
#  ['0.059301000', '189', '74', '1'],
#  ['0.059323001', '28', '116', '0'],
#  ['0.059427001', '39', '115', '0'],
#  ['0.059428001', '96', '143', '0'],
#  ['0.059443000', '139', '173', '0'],
#  ['0.059451001', '87', '144', '0'],
#  ['0.059488000', '23', '51', '0'],
#  ['0.059630000', '92', '144', '0'],
#  ['0.059641001', '195', '87', '0'],
#  ['0.059654000', '185', '98', '0'],
#  ['0.059663001', '38', '116', '0'],
#  ['0.059693001', '111', '52', '0'],
#  ['0.059725000', '32', '117', '0'],
#  ['0.059795001', '119', '48', '0'],
#  ['0.059878001', '23', '52', '0'],
#  ['0.059888001', '138', '161', '0'],
#  ['0.059926001', '180', '151', '0'],
#  ['0.059934000', '177', '152', '0'],
#  ['0.059957001', '32', '39', '1'],
#  ['0.059960000', '39', '116', '0'],
#  ['0.059982000', '109', '53', '0'],
#  ['0.060009001', '39', '51', '0'],
#  ['0.060029000', '239', '158', '1'],
#  ['0.060046000', '34', '40', '1'],
#  ['0.060047001', '86', '144', '0'],
#  ['0.060096000', '190', '97', '0'],
#  ['0.060167000', '86', '145', '0'],
#  ['0.060211001', '17', '49', '0'],
#  ['0.060263001', '142', '171', '0'],
#  ['0.060335000', '29', '106', '1'],
#  ['0.060344001', '38', '104', '1'],
#  ['0.060373000', '28', '53', '0'],
#  ['0.060475000', '238', '158', '1'],
#  ['0.060533000', '29', '39', '1'],
#  ['0.060647001', '138', '154', '1'],
#  ['0.060653000', '176', '153', '0'],
#  ['0.060655001', '103', '142', '0'],
#  ['0.060767000', '143', '171', '0'],
#  ['0.060790001', '169', '137', '1'],
#  ['0.060825001', '135', '75', '1'],
#  ['0.060874000', '23', '39', '1'],
#  ['0.060891000', '171', '156', '0'],
#  ['0.060920001', '84', '138', '1'],
#  ...]

# %%
timestamp, x, y, polarity = [], [], [], []

for tt, xx, yy, pp in lines_read:
    timestamp.append(float(tt))
    x.append(int(xx))
    y.append(int(yy))
    polarity.append(int(pp))

# %%
pos_x, pos_y, pos_t = [], [], []
neg_x, neg_y, neg_t = [], [], []

for i in range(len(polarity)):
    if polarity[i] == 1:
        pos_x.append(x[i])
        pos_y.append(y[i])
        pos_t.append(timestamp[i])
    else:
        neg_x.append(x[i])
        neg_y.append(y[i])
        neg_t.append(timestamp[i])

# %%
print(f'number of events: {len(lines_read)}')
print(f'first timestamp: {timestamp[0]}')
print(f'last timestamp: {timestamp[-1]}')
print(f'maximum x: {max(x)} minimum x: {min(x)}')
print(f'maximum y: {max(y)} minimum y: {min(y)}')

positive_polarity = np.sum(np.where(np.array(polarity) == 1))
negative_polarity = np.sum(np.where(np.array(polarity) == 0))

print(f'positive polarity: {positive_polarity}')
print(f'negative polarity: {negative_polarity}')
# Out:
# number of events: 72046
# first timestamp: 0.0
# last timestamp: 1.0
# maximum x: 239 minimum x: 4
# maximum y: 179 minimum y: 1
# positive polarity: 1120955291
# negative polarity: 1474321744

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, timestamp, c=polarity, label='Events')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Timestamp')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 3D chart (as in exercise 1.1) but only for the first 8000 events.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:8000], y[:8000], timestamp[:8000], c=polarity[:8000], label='events')
ax.view_init(90)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Timestamp')
ax.legend()
plt.tight_layout()
plt.show()

# %%
xs_3 = []
ys_3 = []
ts_3 = []
p_3 = []
for t, x, y, p in lines_read:
    if 0.5 <= float(t) <= 1.0:
        xs_3.append(int(x))
        ys_3.append(int(y))
        ts_3.append(float(t))
        p_3.append(int(p))


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(xs_3, ys_3, ts_3, c=p_3, label='Events')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Timestamp')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 13.3

# %%
lines_1_2 = []
with open('events.txt', 'r') as f:
    for line in f:
        line = line.replace('\n', '').split(' ')
        if float(line[0]) <= 1:
            continue
        if float(line[0]) >= 2:
            break
        lines_1_2.append(line)

timestamps, xs, ys, polarities = [], [], [], []

for timestamp, x, y, polarity in lines_1_2:
    timestamps.append(float(timestamp))
    xs.append(int(x))
    ys.append(int(y))
    polarities.append(1 if int(polarity) else -1)

# %%
print(len(timestamps))
# Out:
# 156431

# %%
def event_frame(event_coordinates, polarities, shape):
    frame = np.zeros(shape) + 127
    frame = frame.astype(np.uint8)

    for i, (x, y) in enumerate(event_coordinates):
        frame[y, x] = 255 if polarities[i] == 1 else 0

    return frame

# %%
tau = 0.01
start_idx = 0
shape = cv2.imread('images/frame_00000000.png').shape

# %%
while start_idx < (len(timestamps) - 1):
    temp_timestamps = []
    temp_coords = []
    temp_polarities = []

    start_time = timestamps[start_idx]

    for i in range(start_idx, len(timestamps)):
        if timestamps[i] - start_time >= tau:
            break
        temp_timestamps.append(timestamps[i])
        temp_coords.append((xs[i], ys[i]))
        temp_polarities.append(polarities[i])

    frame = event_frame(temp_coords, temp_polarities, shape)
    cv2.imshow('Frame', frame)
    # plt.imshow(frame)
    # plt.show()
    key = cv2.waitKey(50)

    if key == 27:  # ESC key
        break


    start_idx = i

cv2.destroyAllWindows()
